# %% [markdown]
# # Hello Success let's talk about Functions
#
# y(x)=2x+5

# %%
def y(x):
    poly = 2*(x) + 5
    return poly

val = y(4)
print(val)
# Out:
# 13

# %%
dict_data =[{"name":"tobi", "scores": {"eng":55,
                                      "math": 75,
                                      "econs":95},
            "class": "ss1",
            "family" : "both"},
            {"name": "manuel", "scores": {"eng": 44,
                                        "math": 65,
                                        "econs": 79},
           "class": "ss2",
           "family": "single"}]
print(dict_data)
# Out:
# [{'name': 'tobi', 'scores': {'eng': 55, 'math': 75, 'econs': 95}, 'class': 'ss1', 'family': 'both'}, {'name': 'manuel', 'scores': {'eng': 44, 'math': 65, 'econs': 79}, 'class': 'ss2', 'family': 'single'}]

# %%
def scores(dict_data):
    new_scores = []
    for i in dict_data:
        arr = []
        score_vals = i["scores"]
        for n, j in score_vals.items():
            arr.append(j)
        new_scores.append(arr)
    return new_scores


scores_val = scores(dict_data)
print(scores_val)
# Out:
# [[55, 75, 95], [44, 65, 79]]

# %%
import statistics as stat
def scores(dict_data):
    new_scores = []
    for i in dict_data:
        arr = []
        score_vals = i["scores"]
        for n, j in score_vals.items():
            arr.append(j)
        new_scores.append(arr)
    return new_scores

def avg_score_val():
    array_mean = []
    scores_val = scores(dict_data)
    for i in scores_val:
        mean_val = round(stat.mean(i), 2)
        array_mean.append(mean_val)
    return array_mean

print(avg_score_val())
# Out:
# [75, 62.67]

# %%
import statistics as s

def scores(dict_data):
    new_scores = []
    for i in dict_data:
        arr = []
        score_vals = i["scores"]
        for n, j in score_vals.items():
            arr.append(j)
        new_scores.append(arr)
    return new_scores


def avg_score(new_scores):
    mean = []
    for i in new_scores:
        a = round(s.mean(i), 2)
        mean.append(a)
    return mean
    


scores = scores(dict_data)
avg = avg_score(scores)
print(avg)
# Out:
# [75, 62.67]

# %%
path = "C:/Users/USER/Documents/My python_folder/Data-cleaning-for-Beginners-main/usa_gov.txt"

# %%
import json as j
records = [j.loads(i) for i in open(path)]
print(records[0:3])
# Out:
# [{'a': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.78 Safari/535.11', 'c': 'US', 'nk': 1, 'tz': 'America/New_York', 'gr': 'MA', 'g': 'A6qOVH', 'h': 'wfLQtf', 'l': 'orofrog', 'al': 'en-US,en;q=0.8', 'hh': '1.usa.gov', 'r': 'http://www.facebook.com/l/7AQEFzjSi/1.usa.gov/wfLQtf', 'u': 'http://www.ncbi.nlm.nih.gov/pubmed/22415991', 't': 1331923247, 'hc': 1331822918, 'cy': 'Danvers', 'll': [42.576698, -70.954903]}, {'a': 'GoogleMaps/RochesterNY', 'c': 'US', 'nk': 0, 'tz': 'America/Denver', 'gr': 'UT', 'g': 'mwszkS', 'h': 'mwszkS', 'l': 'bitly', 'hh': 'j.mp', 'r': 'http://www.AwareMap.com/', 'u': 'http://www.monroecounty.gov/etc/911/rss.php', 't': 1331923249, 'hc': 1308262393, 'cy': 'Provo', 'll': [40.218102, -111.613297]}, {'a': 'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; WOW64; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; .NET4.0E; InfoPath.3)', 'c': 'US', 'nk': 1, 't
# ...

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(records)
df.head()
# Out:
#                                                    a   c   nk  \
# 0  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  US  1.0
# 1                             GoogleMaps/RochesterNY  US  0.0
# 2  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...  US  1.0
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...  BR  0.0
# 4  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  US  0.0
#
#                   tz  gr       g       h         l              al         hh  \
# 0   America/New_York  MA  A6qOVH  wfLQtf   orofrog  en-US,en;q=0.8  1.usa.gov
# 1     America/Denver  UT  mwszkS  mwszkS     bitly             NaN       j.mp
# 2   America/New_York  DC  xxr3Qb  xxr3Qb     bitly           en-US  1.usa.gov
# 3  America/Sao_Paulo  27  zCaLwp  zUtuOu  alelex88           pt-br  1.usa.gov
# 4   America/New_York  MA  9b6kNl  9b6kNl     bitly  en-US,en;q=0.8     bit.ly
#
#                                                    r  \
# 0  http://www.facebook.com/l/7AQEFzjSi/1.usa.gov/...
# ...

# %%
df.columns
# Out:
# Index(['a', 'c', 'nk', 'tz', 'gr', 'g', 'h', 'l', 'al', 'hh', 'r', 'u', 't',
#        'hc', 'cy', 'll', '_heartbeat_', 'kw'],
#       dtype='object')

# %%
df_data = df[["a", "tz", "h", "r", "ll"]]
df_data.head()
# Out:
#                                                    a                 tz  \
# 0  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...   America/New_York
# 1                             GoogleMaps/RochesterNY     America/Denver
# 2  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...   America/New_York
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...  America/Sao_Paulo
# 4  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...   America/New_York
#
#         h                                                  r  \
# 0  wfLQtf  http://www.facebook.com/l/7AQEFzjSi/1.usa.gov/...
# 1  mwszkS                           http://www.AwareMap.com/
# 2  xxr3Qb                               http://t.co/03elZC4Q
# 3  zUtuOu                                             direct
# 4  9b6kNl                http://www.shrewsbury-ma.gov/selco/
#
#                          ll
# 0   [42.576698, -70.954903]
# 1  [40.218102, -111.613297]
# 2     [38.9007, -77.043098]
# 3  [-23.549999, -46.616699]
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3560 entries, 0 to 3559
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   a            3440 non-null   object
#  1   c            2919 non-null   object
#  2   nk           3440 non-null   float64
#  3   tz           3440 non-null   object
#  4   gr           2919 non-null   object
#  5   g            3440 non-null   object
#  6   h            3440 non-null   object
#  7   l            3440 non-null   object
#  8   al           3094 non-null   object
#  9   hh           3440 non-null   object
#  10  r            3440 non-null   object
#  11  u            3440 non-null   object
#  12  t            3440 non-null   float64
#  13  hc           3440 non-null   float64
#  14  cy           2919 non-null   object
#  15  ll           2919 non-null   object
#  16  _heartbeat_  120 non-null    float64
#  17  kw           93 non-null     object
# ...

# %%
df.shape
# Out:
# (3560, 18)

# %%
for i in np.array(df["tz"]):
    print(i)
# Out:
# America/New_York
# America/Denver
# America/New_York
# America/Sao_Paulo
# America/New_York
# America/New_York
# Europe/Warsaw
#
#
#
# America/Los_Angeles
# America/New_York
# America/New_York
# nan
# America/New_York
# Asia/Hong_Kong
# Asia/Hong_Kong
# America/New_York
# America/Denver
# Europe/Rome
# Africa/Ceuta
# America/New_York
# America/New_York
# America/New_York
# Europe/Madrid
# Asia/Kuala_Lumpur
# Asia/Nicosia
# America/Sao_Paulo
#
#
# Europe/London
# America/New_York
# Pacific/Honolulu
# America/Chicago
#
#
# Pacific/Honolulu
#
# America/New_York
# America/New_York
# America/New_York
# America/Chicago
# Europe/Rome
# America/New_York
# America/New_York
# America/Los_Angeles
#
#
# America/New_York
# America/New_York
# Europe/Malta
# America/New_York
# America/New_York
#
# America/Los_Angeles
# nan
# America/Sao_Paulo
#
# Asia/Hong_Kong
# Asia/Hong_Kong
# Pacific/Honolulu
# Pacific/Honolulu
# Pacific/Honolulu
# America/New_York
# Europe/London
# America/New_York
#
# ...

# %%
a = df.isna().sum()
val_na = a.reset_index()
val_na.columns = ["variables", "sum_missing"]

# %%
val_na
# Out:
#       variables  sum_missing
# 0             a          120
# 1             c          641
# 2            nk          120
# 3            tz          120
# 4            gr          641
# 5             g          120
# 6             h          120
# 7             l          120
# 8            al          466
# 9            hh          120
# 10            r          120
# 11            u          120
# 12            t          120
# 13           hc          120
# 14           cy          641
# 15           ll          641
# 16  _heartbeat_         3440
# 17           kw         3467

# %%
df_data.head()
# Out:
#                                                    a                 tz  \
# 0  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...   America/New_York
# 1                             GoogleMaps/RochesterNY     America/Denver
# 2  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...   America/New_York
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...  America/Sao_Paulo
# 4  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...   America/New_York
#
#         h                                                  r  \
# 0  wfLQtf  http://www.facebook.com/l/7AQEFzjSi/1.usa.gov/...
# 1  mwszkS                           http://www.AwareMap.com/
# 2  xxr3Qb                               http://t.co/03elZC4Q
# 3  zUtuOu                                             direct
# 4  9b6kNl                http://www.shrewsbury-ma.gov/selco/
#
#                          ll
# 0   [42.576698, -70.954903]
# 1  [40.218102, -111.613297]
# 2     [38.9007, -77.043098]
# 3  [-23.549999, -46.616699]
# ...

# %%
np.array(df_data.iloc[n])
# Out:
# array(['Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.78 Safari/535.11',
#        'America/New_York', 'wfLQtf',
#        'http://www.facebook.com/l/7AQEFzjSi/1.usa.gov/wfLQtf',
#        list([42.576698, -70.954903])], dtype=object)

# %%
list_array = [0, 5, 11, 13]
for i in list_array:
    print(np.array(df_data.iloc[i]))
# Out:
# ['Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.78 Safari/535.11'
#  'America/New_York' 'wfLQtf'
#  'http://www.facebook.com/l/7AQEFzjSi/1.usa.gov/wfLQtf'
#  list([42.576698, -70.954903])]
# ['Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11'
#  'America/New_York' 'axNK8c' 'http://www.shrewsbury-ma.gov/selco/'
#  list([42.286499, -71.714699])]
# ['Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10.4; en-US; rv:1.9.2.27) Gecko/20120216 Firefox/3.6.27'
#  'America/New_York' 'A0nRz4' 'http://t.co/ND7SoPyo'
#  list([38.937599, -77.092796])]
# [nan nan nan nan nan]

# %%
for n in range(0, 5):
    print(np.array(df_data.iloc[n]))
# Out:
# ['Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.78 Safari/535.11'
#  'America/New_York' 'wfLQtf'
#  'http://www.facebook.com/l/7AQEFzjSi/1.usa.gov/wfLQtf'
#  list([42.576698, -70.954903])]
# ['GoogleMaps/RochesterNY' 'America/Denver' 'mwszkS'
#  'http://www.AwareMap.com/' list([40.218102, -111.613297])]
# ['Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; WOW64; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; .NET4.0E; InfoPath.3)'
#  'America/New_York' 'xxr3Qb' 'http://t.co/03elZC4Q'
#  list([38.9007, -77.043098])]
# ['Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8) AppleWebKit/534.52.7 (KHTML, like Gecko) Version/5.1.2 Safari/534.52.7'
#  'America/Sao_Paulo' 'zUtuOu' 'direct' list([-23.549999, -46.616699])]
# ['Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11'
# ...

# %%
df["tz"].value_counts().head(10)
# Out:
# America/New_York       1251
#                         521
# America/Chicago         400
# America/Los_Angeles     382
# America/Denver          191
# Europe/London            74
# Asia/Tokyo               37
# Pacific/Honolulu         36
# Europe/Madrid            35
# America/Sao_Paulo        33
# Name: tz, dtype: int64

# %%
def counter_col(col):
    dict_count = {}
    for i in np.array(df[col]):
        dict_count[i] = dict_count.get(i,0) + 1
    return dict_count
type(counter_col("tz"))
# Out:
# dict

# %%
keys = []
values =[]
for i, j in counter_col("tz").items():
    keys.append(i)
    values.append(j)

# %%
pd.DataFrame([1, 5, 4], [10, 5, 9],)
# Out:
#     0
# 10  1
# 5   5
# 9   4

# %%
newfile = pd.DataFrame(values, keys, columns=["counts"])
count_df = newfile.reset_index()
count_df.columns = ["timezones", "counts"]
count_df.head(10)
# Out:
#              timezones  counts
# 0     America/New_York    1251
# 1       America/Denver     191
# 2    America/Sao_Paulo      33
# 3        Europe/Warsaw      16
# 4                          521
# 5  America/Los_Angeles     382
# 6                  NaN     120
# 7       Asia/Hong_Kong      10
# 8          Europe/Rome      27
# 9         Africa/Ceuta       2

# %%
for i, j in counter_col("cy").items():
    print(i)
data = list(counter_col("tz"))
type(data)
# Out:
# Danvers
# Provo
# Washington
# Braz
# Shrewsbury
# Luban
# nan
# Seattle
# Alexandria
# Marietta
# Central District
# Buckfield
# Venice
# Alcal
# Davidsonville
# Hockessin
# Lititz
# Bilbao
# Kuala Lumpur
# Nicosia
# SPaulo
# Huddersfield
# Fairport
# Honolulu
# Knoxville
# Stamford
# Bronx
# Saint Louis
# Rome
# Dudley
# Bowie
# Los Angeles
# Savannah
# Sliema
# Woodbridge
# Grand Rapids
# Chula Vista
# Curitiba
# Cambridge
# Birmingham
# Paramus
# Lisboa
# Lambersart
# Bodmin
# Herning
# Piombino
# White Plains
# London
# Columbus
# Mesquite
# Farmington
# Limeil-brnnes
# San Francisco
# Durango
# Dublin
# Kennesaw
# A Po Long
# Jersey City
# Li
# Warrington
# Surrey
# Mount Laurel
# Tholen
# Brno
# Burke
# Ruther Glen
# Stockholm
# Hartland
# Belo Horizonte
# Bethel
# Brooklyn
# Larchmont
# Melaka
# Houston
# Huntsville
# Needham
# Si Sa Ket
# Oldenburg
# Bellevue
# Albuquerque
# Crespellano
# Yalaha
# Summerville
# Toronto
# Berkeley
# Cincinnati
# Vernon Rockville
# Cracow
# ...

# %%
df["tz"].isna().sum()
# Out:
# 120

# %%
clean_tz = df['tz'].fillna("missing")
clean_tz.value_counts().head(10)
# Out:
# America/New_York       1251
#                         521
# America/Chicago         400
# America/Los_Angeles     382
# America/Denver          191
# missing                 120
# Europe/London            74
# Asia/Tokyo               37
# Pacific/Honolulu         36
# Europe/Madrid            35
# Name: tz, dtype: int64

# %%
clean_tz[clean_tz == ""].value_counts()
# Out:
#     521
# Name: tz, dtype: int64

# %%
clean_tz[clean_tz == ""] = "unknown"

# %%
clean_tz.value_counts().head(10)
# Out:
# America/New_York       1251
# unknown                 521
# America/Chicago         400
# America/Los_Angeles     382
# America/Denver          191
# missing                 120
# Europe/London            74
# Asia/Tokyo               37
# Pacific/Honolulu         36
# Europe/Madrid            35
# Name: tz, dtype: int64

# %%
df["tz"] = clean_tz
df.head()
# Out:
#                                                    a   c   nk  \
# 0  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  US  1.0
# 1                             GoogleMaps/RochesterNY  US  0.0
# 2  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...  US  1.0
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...  BR  0.0
# 4  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  US  0.0
#
#                   tz  gr       g       h         l              al         hh  \
# 0   America/New_York  MA  A6qOVH  wfLQtf   orofrog  en-US,en;q=0.8  1.usa.gov
# 1     America/Denver  UT  mwszkS  mwszkS     bitly             NaN       j.mp
# 2   America/New_York  DC  xxr3Qb  xxr3Qb     bitly           en-US  1.usa.gov
# 3  America/Sao_Paulo  27  zCaLwp  zUtuOu  alelex88           pt-br  1.usa.gov
# 4   America/New_York  MA  9b6kNl  9b6kNl     bitly  en-US,en;q=0.8     bit.ly
#
#                                                    r  \
# 0  http://www.facebook.com/l/7AQEFzjSi/1.usa.gov/...
# ...

# %%
df["tz"].value_counts().head(10)
# Out:
# America/New_York       1251
# unknown                 521
# America/Chicago         400
# America/Los_Angeles     382
# America/Denver          191
# missing                 120
# Europe/London            74
# Asia/Tokyo               37
# Pacific/Honolulu         36
# Europe/Madrid            35
# Name: tz, dtype: int64

# %%
df[df["tz"] == "unknown"]
# Out:
#                                                       a     c   nk       tz  \
# 7     Mozilla/5.0 (Windows NT 6.1; rv:2.0.1) Gecko/2...  None  0.0  unknown
# 8     Opera/9.80 (X11; Linux zbov; U; en) Presto/2.1...  None  0.0  unknown
# 9     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  None  0.0  unknown
# 28    Mozilla/5.0 (iPad; CPU OS 5_0_1 like Mac OS X)...  None  0.0  unknown
# 29    Mozilla/5.0 (iPad; U; CPU OS 3_2 like Mac OS X...  None  1.0  unknown
# ...                                                 ...   ...  ...      ...
# 3512  Mozilla/5.0 (iPad; U; CPU OS 4_3_5 like Mac OS...  None  0.0  unknown
# 3513  Mozilla/5.0 (Windows NT 6.1; rv:10.0.2) Gecko/...  None  0.0  unknown
# 3531  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_6...  None  0.0  unknown
# 3536  Mozilla/5.0 (BlackBerry; U; BlackBerry 9800; e...  None  0.0  unknown
# 3551  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  None  0.0  unknown
#
#        gr       g       h               l  \
# ...

# %%
new_df = df.drop(["tz"], axis = 1)
new_df.head()
# Out:
#                                                    a   c   nk  gr       g  \
# 0  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  US  1.0  MA  A6qOVH
# 1                             GoogleMaps/RochesterNY  US  0.0  UT  mwszkS
# 2  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...  US  1.0  DC  xxr3Qb
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...  BR  0.0  27  zCaLwp
# 4  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  US  0.0  MA  9b6kNl
#
#         h         l              al         hh  \
# 0  wfLQtf   orofrog  en-US,en;q=0.8  1.usa.gov
# 1  mwszkS     bitly             NaN       j.mp
# 2  xxr3Qb     bitly           en-US  1.usa.gov
# 3  zUtuOu  alelex88           pt-br  1.usa.gov
# 4  9b6kNl     bitly  en-US,en;q=0.8     bit.ly
#
#                                                    r  \
# 0  http://www.facebook.com/l/7AQEFzjSi/1.usa.gov/...
# 1                           http://www.AwareMap.com/
# 2                               http://t.co/03elZC4Q
# ...

# %%
df_clean = new_df.fillna("missing")

# %%
df_clean.head(40)
# Out:
#                                                     a        c       nk  \
# 0   Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...       US      1.0
# 1                              GoogleMaps/RochesterNY       US      0.0
# 2   Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...       US      1.0
# 3   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...       BR      0.0
# 4   Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...       US      0.0
# 5   Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...       US      0.0
# 6   Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.1...       PL      0.0
# 7   Mozilla/5.0 (Windows NT 6.1; rv:2.0.1) Gecko/2...  missing      0.0
# 8   Opera/9.80 (X11; Linux zbov; U; en) Presto/2.1...  missing      0.0
# 9   Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  missing      0.0
# 10  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:10.0.2)...       US      1.0
# 11  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10.4...       US      0.0
# ...

# %%
new_df = df.copy()

# %%
new_df
# Out:
#                                                       a   c   nk  \
# 0     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  US  1.0
# 1                                GoogleMaps/RochesterNY  US  0.0
# 2     Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...  US  1.0
# 3     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...  BR  0.0
# 4     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  US  0.0
# ...                                                 ...  ..  ...
# 3555  Mozilla/4.0 (compatible; MSIE 9.0; Windows NT ...  US  1.0
# 3556  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.1...  US  0.0
# 3557                             GoogleMaps/RochesterNY  US  0.0
# 3558                                     GoogleProducer  US  0.0
# 3559  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...  US  0.0
#
#                        tz  gr       g       h             l              al  \
# 0        America/New_York  MA  A6qOVH  wfLQtf       orofrog  en-US,en;q=0.8
# ...

# %% [markdown]
# # your preffered split method

# %%
new_df['a']
# Out:
# 0       Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 1                                  GoogleMaps/RochesterNY
# 2       Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...
# 3       Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...
# 4       Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
#                               ...
# 3555    Mozilla/4.0 (compatible; MSIE 9.0; Windows NT ...
# 3556    Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.1...
# 3557                               GoogleMaps/RochesterNY
# 3558                                       GoogleProducer
# 3559    Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...
# Name: a, Length: 3560, dtype: object

# %%
array_val = []
for i in np.array(new_df["a"]):
        b = str(i)
        a = b.split(" ")[0]
        array_val.append(a)
print(len(array_val))
# Out:
# 3560

# %%
df.shape
# Out:
# (3560, 18)

# %%
df_val = pd.DataFrame(array_val, columns=["prefered_browsers"])
df_val.head()
# Out:
#         prefered_browsers
# 0             Mozilla/5.0
# 1  GoogleMaps/RochesterNY
# 2             Mozilla/4.0
# 3             Mozilla/5.0
# 4             Mozilla/5.0

# %%
df_value = pd.concat([df_val, new_df], axis=1)
df_value.head()
# Out:
#         prefered_browsers                                                  a  \
# 0             Mozilla/5.0  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 1  GoogleMaps/RochesterNY                             GoogleMaps/RochesterNY
# 2             Mozilla/4.0  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...
# 3             Mozilla/5.0  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...
# 4             Mozilla/5.0  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
#
#     c   nk                 tz  gr       g       h         l              al  \
# 0  US  1.0   America/New_York  MA  A6qOVH  wfLQtf   orofrog  en-US,en;q=0.8
# 1  US  0.0     America/Denver  UT  mwszkS  mwszkS     bitly             NaN
# 2  US  1.0   America/New_York  DC  xxr3Qb  xxr3Qb     bitly           en-US
# 3  BR  0.0  America/Sao_Paulo  27  zCaLwp  zUtuOu  alelex88           pt-br
# 4  US  0.0   America/New_York  MA  9b6kNl  9b6kNl     bitly  en-US,en;q=0.8
#
# ...

# %% [markdown]
# # easy split method using split

# %%
new_df["browsers"] = pd.Series([x.split()[0] for x in new_df.a.dropna()])
new_df.head()
# Out:
#                                                    a   c   nk  \
# 0  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  US  1.0
# 1                             GoogleMaps/RochesterNY  US  0.0
# 2  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...  US  1.0
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...  BR  0.0
# 4  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  US  0.0
#
#                   tz  gr       g       h         l              al         hh  \
# 0   America/New_York  MA  A6qOVH  wfLQtf   orofrog  en-US,en;q=0.8  1.usa.gov
# 1     America/Denver  UT  mwszkS  mwszkS     bitly             NaN       j.mp
# 2   America/New_York  DC  xxr3Qb  xxr3Qb     bitly           en-US  1.usa.gov
# 3  America/Sao_Paulo  27  zCaLwp  zUtuOu  alelex88           pt-br  1.usa.gov
# 4   America/New_York  MA  9b6kNl  9b6kNl     bitly  en-US,en;q=0.8     bit.ly
#
#                                                    r  \
# 0  http://www.facebook.com/l/7AQEFzjSi/1.usa.gov/...
# ...
